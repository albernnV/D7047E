# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# # Loading the dataset

# %%
train_set = tf.keras.preprocessing.image_dataset_from_directory(
    directory="chest_xray/train", labels='inferred', label_mode='categorical',
    class_names=["NORMAL", "PNEUMONIA"], color_mode='rgb', batch_size=32, image_size=(224,
    224), shuffle=True, seed=None, validation_split=None, subset=None,
    interpolation='bilinear', follow_links=False
)

val_set = tf.keras.preprocessing.image_dataset_from_directory(
    directory="chest_xray/val", labels='inferred', label_mode='categorical',
    class_names=["NORMAL", "PNEUMONIA"], color_mode='grayscale', batch_size=32, image_size=(224,
    224), shuffle=True, seed=None, validation_split=None, subset=None,
    interpolation='bilinear', follow_links=False
)

test_set = tf.keras.preprocessing.image_dataset_from_directory(
    directory="chest_xray/test", labels='inferred', label_mode='categorical',
    class_names=["NORMAL", "PNEUMONIA"], color_mode='grayscale', batch_size=32, image_size=(224,
    224), shuffle=True, seed=None, validation_split=None, subset=None,
    interpolation='bilinear', follow_links=False
)
# Out:
# Found 5216 files belonging to 2 classes.
# Found 16 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_set.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-ef71b533a81b> in <module>
#       4         ax = plt.subplot(3, 3, i + 1)
#       5         plt.imshow(images[i].numpy().astype("uint8"))
# ----> 6         plt.title(int(labels[i]))
#       7         plt.axis("off")
#
# D:\anaconda\envs\autoencoder\lib\site-packages\tensorflow\python\framework\ops.py in __int__(self)
#     978
#     979   def __int__(self):
# --> 980     return int(self._numpy())
#     981
#     982   def __long__(self):
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
for image_batch, labels_batch in train_set:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 224, 224, 3)
# (32, 2)

# %% [markdown]
# ## Standardizing the data

# %%
from tensorflow.keras import layers

normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
train_set = train_set.map(lambda x, y: (normalization_layer(x), y))
val_set = val_set.map(lambda x, y: (normalization_layer(x), y))
test_set = test_set.map(lambda x, y: (normalization_layer(x), y))

# %% [markdown]
# ## Configure the dataset for performance

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_set = train_set.cache().prefetch(buffer_size=AUTOTUNE)
val_set = val_set.cache().prefetch(buffer_size=AUTOTUNE)
test_set = test_set.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Training ResNet on the dataset

# %%
resNetModel = tf.keras.applications.ResNet50(
    include_top=True,
    weights=None,
    input_tensor=None,
    input_shape=(224, 224, 3),
    pooling=None,
    classes=2
)

# %%
resNetModel.compile(
  optimizer='adam',
  loss=tf.losses.BinaryCrossentropy(from_logits=False),
  metrics=['accuracy'])

# %%
history = resNetModel.fit(train_set, batch_size=32, epochs=10, validation_data=val_set)
# Out:
# Epoch 1/10
# 163/163 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9450WARNING:tensorflow:Model was constructed with shape (None, 224, 224, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_4'), name='input_4', description="created by layer 'input_4'"), but it was called on an input with incompatible shape (None, 224, 224, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-7282af1b2928> in <module>
# ----> 1 history = resNetModel.fit(train_set, batch_size=32, epochs=10, validation_data=val_set)
#
# ...
